# %% [markdown]
# ### Analisis data
#
# Data berisi informasi dari segala sesuatu informasi mengenai tentang study diluarnegri.
# Informasi berisi:
# 1. Negara,Kota
# 2. Universitas, Jurusan, tingkatan
# 3. Biaya kesaharian, Biaya kuliah, Biaya Rumah ect

# %% [markdown]
# #### Pemanggilan library

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("International_Education_Costs.csv")
df.shape
# Out:
# (907, 12)

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# 2               72.5      1600           235            900           1.35
# 3               71.2      1400           450            650           1.52
# 4               70.5      1100            75            550           0.92

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            907 non-null    object
#  1   City               907 non-null    object
#  2   University         907 non-null    object
#  3   Program            907 non-null    object
#  4   Level              907 non-null    object
#  5   Duration_Years     907 non-null    float64
#  6   Tuition_USD        907 non-null    int64
#  7   Living_Cost_Index  907 non-null    float64
#  8   Rent_USD           907 non-null    int64
#  9   Visa_Fee_USD       907 non-null    int64
#  10  Insurance_USD      907 non-null    int64
#  11  Exchange_Rate      907 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 85.2+ KB

# %% [markdown]
# data memiliki 12 column dan 907 baris

# %% [markdown]
# ____

# %% [markdown]
# #### Cleaning data set

# %% [markdown]
# 1. cek dan ganti nilai null

# %%
df.isnull().sum()
# Out:
# Country              0
# City                 0
# University           0
# Program              0
# Level                0
# Duration_Years       0
# Tuition_USD          0
# Living_Cost_Index    0
# Rent_USD             0
# Visa_Fee_USD         0
# Insurance_USD        0
# Exchange_Rate        0
# dtype: int64

# %% [markdown]
# 2. cek dan hapus data duplicate

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Analisis data

# %% [markdown]
# 1. penambahan variable columns untuk menjelaskan harga sewa selama 1 tahun

# %%
df["Rent/year"]= df["Rent_USD"]* 12
df["total"]=df["Tuition_USD"]+ df["Rent/year"]+df["Visa_Fee_USD"]
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate  \
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# 2               72.5      1600           235            900           1.35
# 3               71.2      1400           450            650           1.52
# 4               70.5      1100            75            550           0.92
#
#    Rent/year  total
# 0      26400  81960
# 1      21600  63285
# 2      19200  57935
# 3      16800  59250
# 4      13200  13775

# %% [markdown]
# 2. Central Tedency

# %%
df.describe()
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate    Rent/year         total
# count    907.000000     907.000000     907.000000    907.00000    907.000000
# mean     211.396913     700.077178     623.000695  11630.47409  28546.887541
# std      143.435740     320.374875    3801.746134   6205.85703  21581.530364
# min       40.000000     200.000000       0.150000   1800.00000   2850.000000
# 25%      100.000000     450.000000       0.920000   6540.00000  10910.000000
# 50%      160.000000     650.000000       1.350000  10800.00000  17940.000000
# 75%      240.000000     800.000000       7.150000  15600.00000  45575.000000
# max      490.000000    1500.000000   42150.000000  30000.00000  92160.000000

# %%
# mean costan
analist_1=df.describe()

analist_1
# Out:
#        Duration_Years   Tuition_USD  Living_Cost_Index     Rent_USD  \
# count      907.000000    907.000000         907.000000   907.000000
# mean         2.836825  16705.016538          64.437486   969.206174
# std          0.945449  16582.385275          14.056333   517.154752
# min          1.000000      0.000000          27.800000   150.000000
# 25%          2.000000   2850.000000          56.300000   545.000000
# 50%          3.000000   7500.000000          67.500000   900.000000
# 75%          4.000000  31100.000000          72.200000  1300.000000
# max          5.000000  62000.000000         122.400000  2500.000000
#
#        Visa_Fee_USD  Insurance_USD  Exchange_Rate    Rent/year         total
# count    907.000000     907.000000     907.000000    907.00000    907.000000
# mean     211.396913     700.077178     623.000695  11630.47409  28546.887541
# std      143.435740     320.374875    3801.746134   6205.85703  21581.530364
# min       40.000000     200.000000       0.150000   1800.00000   2850.000000
# 25%      100.000000     450.000000       0.920000   6540.00000  10910.000000
# 50%      160.000000     650.000000       1.350000  10800.00000  17940.000000
# 75%      240.000000     800.000000       7.150000  15600.00000  45575.000000
# max      490.000000    1500.000000   42150.000000  30000.00000  92160.000000

# %%
analist =pd.DataFrame(
    {
        "variable":["Tuition_USD", "Living_Cost_Index", "Exchange_Rate","Total/year"],
        "Means": [analist_1["Tuition_USD"].loc["mean"],
                  analist_1["Living_Cost_Index"].loc["mean"],
                  analist_1["Exchange_Rate"].loc["mean"],
                  analist_1["total"].loc["mean"]]
}
)
#Table info Average Cost in Students Interantional
print ("Average for Cost International Students")

analist.head()
# Out:
# Average for Cost International Students
#             variable         Means
# 0        Tuition_USD  16705.016538
# 1  Living_Cost_Index     64.437486
# 2      Exchange_Rate    623.000695
# 3         Total/year  28546.887541

# %% [markdown]
# 3. Top negara yang menyediakan pendidikan international

# %%
#Countries
from collections  import Counter
country= Counter (df["Country"])
x=[name for name in country.keys()]
y =[country[name]for name in x]
country=pd.DataFrame(
    {
        "Country":x,
        "value":y
    }
)
country.to_csv("country.csv")
top_ =country.sort_values (by ='value', ascending= False)
top_.head(10)
# Out:
#         Country  value
# 1            UK     93
# 3     Australia     86
# 0           USA     78
# 2        Canada     76
# 4       Germany     33
# 8        France     27
# 13  South Korea     23
# 6   Netherlands     21
# 9   Switzerland     20
# 7     Singapore     18

# %% [markdown]
# 3. Informasi mengenai tingkatan pendidikan yang tersedia

# %%
# information degrees 
import matplotlib.pyplot as plt
# phd/bachelor/ Majister 
Data3=Counter(df["Level"])
x=[level for level in Data3.keys()]
y=[Data3[name] for name in x]
data3=pd.DataFrame({
    "level":x,
    "quantity":y
})
data3.to_csv("level1", index=False)
print("level and quantity")
plt.pie(y,labels=x)
plt.show()

#mean duration study/level

data4= df.groupby(["Level"])["Duration_Years"].mean()

print (data4)
data4.to_csv("duration_level.csv")
# Out:
# level and quantity
#           Duration_Years
# Level
# Bachelor        3.464646
# Master          1.984479
# PhD             4.081761

# %%
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate  \
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# 2               72.5      1600           235            900           1.35
# 3               71.2      1400           450            650           1.52
# 4               70.5      1100            75            550           0.92
#
#    Rent/year  total
# 0      26400  81960
# 1      21600  63285
# 2      19200  57935
# 3      16800  59250
# 4      13200  13775

# %% [markdown]
# 4. Universitas gratis

# %%
# information univesty tuition==0
data5 =df.loc[df["Tuition_USD"]==0, ["University","Program","Level","Country","total"]]
data5
# Out:
#                           University                 Program     Level  \
# 10               KTH Royal Institute  Sustainable Technology    Master
# 11          University of Copenhagen          Bioinformatics    Master
# 39                   Lund University            Neuroscience       PhD
# 45                Aalborg University        Computer Science  Bachelor
# 54         Free University of Berlin  International Business  Bachelor
# ..                               ...                     ...       ...
# 754  National University of La Plata    Software Development  Bachelor
# 761      National University of Cuyo          Data Analytics       PhD
# 770      Universidad de la Republica    Computer Engineering       PhD
# 794                             UTEC     Information Systems  Bachelor
# 802          Universidad de Paysandu    Software Engineering    Master
#
#        Country  total
# 10      Sweden  14510
# 11     Denmark  15720
# 39      Sweden  12110
# 45     Denmark  10920
# 54     Germany  10875
# ..         ...    ...
# 754  Argentina   2970
# 761  Argentina   2850
# 770    Uruguay   5490
# 794    Uruguay   4290
# 802    Uruguay   4050
#
# [103 rows x 5 columns]

# %% [markdown]
# 5. prodi yang diminati

# %%
# most 
Program=df["Program"]
Program=Counter(Program)
x=[k for k in Program.keys()]
y=[Program[k] for k in x ]
data6= pd.DataFrame(
    {
        "Program Study":x,
        "Quantity":y
    }
)
data6 = data6.sort_values ("Quantity", ascending=True)

data6_1=data6.sort_values("Quantity",ascending=False).head(5)
plt.bar(data6_1["Program Study"],data6_1["Quantity"])
plt.show()

# %% [markdown]
# 6. Kebutuhan semua aspek keuagan pendidikan Internationl

# %%
data7=df.groupby(["Country"])[["Tuition_USD","Rent/year","Visa_Fee_USD","total"]].sum()
data7=pd.DataFrame(data7)
data7=data7.sort_values("Tuition_USD", ascending=True)

data7_ =pd.read_csv("data7.csv").sort_values("Tuition_USD")
plt.plot(data7_["Country"],data7_["Tuition_USD"])
plt.plot(data7_["Country"],data7_["Rent/year"])
plt.plot(data7_["Country"],data7_["Visa_Fee_USD"])
plt.plot(data7_["Country"],data7_["total"])
plt.show ()

# %% [markdown]
# Grafik diurutkan berdasarkan biaya kuliah dari yang terkecil ke yang terbesar dikelompokkan dalam satu negara.
# Semua aspek biaya kehidupan meningkat jika biaya kuliahnya besar. Kebutuhan yang besar juga dipengaruh oleh wilayah juga.
